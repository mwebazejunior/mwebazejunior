# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
employee_data = '/content/drive/MyDrive/Week2_data/Mod_employee_attrition - Temp employee_attrition.csv'
df = pd.read_csv(employee_data)
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# **Identify and address any duplicate values**

# %%
#https://www.geeksforgeeks.org/find-duplicate-rows-in-a-dataframe-based-on-all-or-selected-columns/
print(df.duplicated().value_counts())

# %%
df.duplicated().sum()
# Out:
# 5

# %%
#https://stackabuse.com/handling-duplicate-values-in-a-pandas-dataframe/
df.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      41       Yes      Travel_Rarely                   Sales
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 3      33        No  Travel_Frequently  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1470   36        No  Travel_Frequently  Research & Development
# 1471   39        No      Travel_Rarely  Research & Development
# 1472   27        No      Travel_Rarely  Research & Development
# 1473   49        No  Travel_Frequently                   Sales
# 1474   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().value_counts())
# Out:
# False    1470
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Ensure all columns match the data types listed in the data dictionary.**
#
# #https://www.geeksforgeeks.org/change-data-type-for-one-or-more-columns-in-pandas-dataframe/

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                  object
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# DailyRate                    int64
# WeeklyRate                   int64
# YearlyRate                   int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#https://www.geeksforgeeks.org/replace-values-in-pandas-dataframe-using-regex/
df['HourlyRate'] = df['HourlyRate'].replace(regex=True, to_replace=r'\D', value='')

# %%
df['HourlyRate'] = pd.to_numeric(df['HourlyRate'])

# %%
df['HourlyRate'] = df['HourlyRate'].astype(str).astype(int)
df.HourlyRate.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# DailyRate                    int64
# WeeklyRate                   int64
# YearlyRate                   int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df['YearsAtCompany'] = df['YearsAtCompany'].replace(regex=True, to_replace=r'\D', value='')

# %%
df['YearsAtCompany'] = df['YearsAtCompany'].astype(str).astype(int)

# %%
df.YearsAtCompany.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# DailyRate                    int64
# WeeklyRate                   int64
# YearlyRate                   int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#https://www.dataquest.io/blog/grouping-data-a-step-by-step-tutorial-to-groupby-in-pandas/
grouped_df = df.groupby('Gender').count()
#df.group_by('gender').count()
grouped_df

# %%
null_values_column_A = df[df['Gender'].isnull()]

print("Null values in column 'A':")
print(null_values_column_A)
# Out:
# Null values in column 'A':
#       Age Attrition     BusinessTravel              Department  \
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# 5      32        No  Travel_Frequently  Research & Development
# 7      30        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1470   36        No  Travel_Frequently  Research & Development
# 1471   39        No      Travel_Rarely  Research & Development
# 1472   27        No      Travel_Rarely  Research & Development
# 1473   49        No  Travel_Frequently                   Sales
# 1474   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1                    8          1  Life Sciences              1
# ...

# %%
value = df['EmployeeNumber'][2]
value
# Out:
# 4

# %%
#null rows
#index = df['EmployeeNumber'].index('2')
index = df[df['EmployeeNumber'] == '2061']
index
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, DailyRate, WeeklyRate, YearlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
#https://saturncloud.io/blog/how-to-replace-none-with-nan-in-pandas-dataframe/

#df_filled = df.fillna(placeholder_value)
#placeholder = -1
df['Gender'] = df['Gender'].fillna(placeholder_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4cc3072c3049> in <cell line: 4>()
#       2 #df_filled = df.fillna(placeholder_value)
#       3 #placeholder = -1
# ----> 4 df['Gender'] = df['Gender'].fillna(placeholder_value)
#
# NameError: name 'df' is not defined

# %%
grouped_df = df.groupby('Gender').count()
#df.group_by('gender').count()
grouped_df
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# Gender
# Female  588        588             588         588               588
#
#         Education  EducationField  EmployeeCount  EmployeeNumber  \
# Gender
# Female        588             588            588             588
#
#         EnvironmentSatisfaction  ...  RelationshipSatisfaction  StandardHours  \
# Gender                           ...
# Female                      588  ...                       588            588
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# Gender
# Female               588                588                    588
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Gender
# Female              588             588                 588
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# Gender
# Female                      588                   588
#
# [1 rows x 34 columns]

# %%
#group by Gender into categorical column
f['Gender'] = pd.Categorical(df['Gender'])
df['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1470      Male
# 1471      Male
# 1472      Male
# 1473      Male
# 1474      Male
# Name: Gender, Length: 1470, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
#https://www.statology.org/seaborn-boxplot-remove-outliers/
import seaborn as sns
sns.boxplot(y=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
#https://datagy.io/python-z-score/
import numpy as np
z_scores = np.abs((df['Age'] - df['Age'].mean()) / df['Age'].std())
# Define threshold for outlier detection
threshold = 3
# Identify outliers
outliers = df[z_scores > threshold]
print("Identified outliers:")
print(outliers)
# Replace outliers with NaN
df.loc[z_scores > threshold, 'Age'] = np.nan
# Impute missing values (e.g., replace with mean)
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Age']

# %%
sns.boxplot(y=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
df['Department'].value_counts().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: ylabel='Department'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',100)

# %%
#ns.barplot(df['Department'],df['Gender'],df['Age'])
ax = sns.countplot(data=df, x='Department', hue='Gender')

# %%
ax = sns.countplot(data=df, x='Department', hue='Age')
