# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
sales_data ='/content/drive/MyDrive/Week2_data/Machine Learning Data Sets/cereal-kaggle-crawford-modified - sheet 1.csv'
df = pd.read_csv(sales_data)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C       NaN        4  1.0     130   10.0
# 1          100% Natural Bran   Q    C     120.0        3  5.0      15    2.0
# 2                   All-Bran   K    C      70.0        4  1.0     260    9.0
# 3  All-Bran with Extra Fiber   K    C      50.0        4  0.0     140   14.0
# 4             Almond Delight   R    C       NaN        2  2.0     200    1.0
#
#    carbo  sugars  potass  vitamins shelf  weight  cups     rating
# 0    5.0     6.0     280        25   top     1.0  0.33  68.402973
# 1    8.0     8.0     135         0   top     1.0  1.00  33.983679
# 2    7.0     5.0     320        25   top     1.0  0.33  59.425505
# 3    8.0     0.0     330        25   top     1.0  0.50  93.704912
# 4   14.0     8.0      -1        25   NaN     1.0  0.75  34.384843

# %%
# Define features and target
X = df.drop(columns = 'rating')
y = df['rating']
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',100)
import missingno
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
# Set pandas as the default output for sklearn
from sklearn import set_config
set_config(transform_output='pandas')

# Making a numeric tuple for ColumnTransformer
# PREPROCESSING PIPELINE FOR NUMERIC DATA
# Save list of column names
numeric_columns = X_train.select_dtypes("number").columns
categorical_columns = X_train.select_dtypes(exclude=['number']).columns
# Instantiate the imputer object from the SimpleImputer class with strategy 'median'
impute_median = SimpleImputer(strategy='median')
scaler = StandardScaler()
# Fit the imputer object on the numeric training data with .fit()
impute_median.fit(X_train[numeric_columns])
# Transform the training data
#X_train_num_imputed = impute_median.transform(X_train[numeric_columns])
X_train_processed = impute_median.transform(X_train[numeric_columns])
# Transfrom the testing data
#X_test_num_imputed = impute_median.transform(X_test[numeric_columns])
X_test_processed = impute_median.transform(X_test[numeric_columns])
# Make a numeric preprocessing pipeline
numeric_pipeline = make_pipeline(impute_median, scaler)
numeric_pipeline

# Pipeline 1: For numeric columns
numeric_pipeline = make_pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])
numeric_pipeline_tuple = ('numeric_pipeline', numeric_pipeline, numeric_columns)
# Pipeline 2: For categorical columns
categorical_pipeline = make_pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent'))
])
categorical_pipeline_tuple = ('categorical_pipeline', categorical_pipeline, categorical_columns)

# Pipeline 3: For both numeric and categorical columns (using ColumnTransformer)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline, numeric_columns),
        ('cat', categorical_pipeline, categorical_columns)
    ]
)
column_transformer_tuple = ('Column_Transformer', preprocessor, numeric_columns, categorical_columns)

# Print the tuples
print("Pipeline 1:", numeric_pipeline_tuple)
print("Pipeline 2:", categorical_pipeline_tuple)
print("Pipeline 3:", column_transformer_tuple)
# Out:
# Pipeline 1: ('numeric_pipeline', Pipeline(steps=[('list',
#                  [('imputer', SimpleImputer()), ('scaler', StandardScaler())])]), Index(['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars',
#        'potass', 'vitamins', 'weight', 'cups'],
#       dtype='object'))
# Pipeline 2: ('categorical_pipeline', Pipeline(steps=[('list',
#                  [('imputer', SimpleImputer(strategy='most_frequent'))])]), Index(['name', 'mfr', 'type', 'shelf'], dtype='object'))
# Pipeline 3: ('Column_Transformer', ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('list',
#                                                   [('imputer', SimpleImputer()),
#                                                    ('scaler',
#                                                     StandardScaler())])]),
#                                  Index(['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars',
#        'potass', 'vitamins', 'weight', 'cups'],
#       dtype='object')),
#                                 ('cat',
#                                  Pipeline(steps=[('list',
#                                                   [('imputer',
#                                                     SimpleImputer(strategy='most_frequent'))])]),
#                                  Index(['name', 'mfr', 'type', 'shelf'], dtype='object'))]), Index(['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars',
#        'potass', 'vitamins', 'weight', 'cups'],
#       dtype='object'), Index(['name', 'mfr', 'type', 'shelf'], dtype='object'))

# %%
X_train.head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 30               Golden Crisp   P    C     100.0        2  0.0      45    0.0
# 40                        Kix   G    C     110.0        2  1.0     260    0.0
# 39     Just Right Fruit & Nut   K    C     140.0        3  1.0     170    2.0
# 16                Corn Flakes   K    C     100.0        2  0.0     290    1.0
# 65  Shredded Wheat spoon size   N    C      90.0        3  0.0       0    3.0
#
#     carbo  sugars  potass  vitamins   shelf  weight  cups
# 30   11.0    15.0      40        25  bottom     1.0  0.88
# 40   21.0     3.0      40        25  middle     1.0  1.50
# 39   20.0     9.0      95       100     top     1.3  0.75
# 16   21.0     2.0      35        25  bottom     1.0  1.00
# 65   20.0     0.0     120         0  bottom     1.0  0.67

# %%
X_train_processed.head()
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 30     100.0      2.0  0.0    45.0    0.0   11.0    15.0    40.0      25.0
# 40     110.0      2.0  1.0   260.0    0.0   21.0     3.0    40.0      25.0
# 39     140.0      3.0  1.0   170.0    2.0   20.0     9.0    95.0     100.0
# 16     100.0      2.0  0.0   290.0    1.0   21.0     2.0    35.0      25.0
# 65      90.0      3.0  0.0     0.0    3.0   20.0     0.0   120.0       0.0
#
#     weight  cups
# 30     1.0  0.88
# 40     1.0  1.50
# 39     1.3  0.75
# 16     1.0  1.00
# 65     1.0  0.67

# %%
X_test.head()
# Out:
#                                  name mfr type  calories  protein  fat  \
# 4                      Almond Delight   R    C       NaN        2  2.0
# 35                   Honey Graham Ohs   Q    C       NaN        1  2.0
# 10                       Cap'n'Crunch   Q    C       NaN        1  2.0
# 0                           100% Bran   N    C       NaN        4  1.0
# 45  Muesli Raisins; Peaches; & Pecans   R    C       NaN        4  3.0
#
#     sodium  fiber  carbo  sugars  potass  vitamins   shelf  weight  cups
# 4      200    1.0   14.0     8.0      -1        25     NaN     1.0  0.75
# 35     220    1.0   12.0    11.0      45        25     NaN     1.0  1.00
# 10     220    0.0   12.0    12.0      35        25  middle     1.0  0.75
# 0      130   10.0    5.0     6.0     280        25     top     1.0  0.33
# 45     150    3.0   16.0    11.0     170        25     top     1.0  1.00

# %%
X_test_processed.head()
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 4      110.0      2.0  2.0   200.0    1.0   14.0     8.0    -1.0      25.0
# 35     110.0      1.0  2.0   220.0    1.0   12.0    11.0    45.0      25.0
# 10     110.0      1.0  2.0   220.0    0.0   12.0    12.0    35.0      25.0
# 0      110.0      4.0  1.0   130.0   10.0    5.0     6.0   280.0      25.0
# 45     110.0      4.0  3.0   150.0    3.0   16.0    11.0   170.0      25.0
#
#     weight  cups
# 4      1.0  0.75
# 35     1.0  1.00
# 10     1.0  0.75
# 0      1.0  0.33
# 45     1.0  1.00

# %%
# Instantiate with verbose_feature_names_out=False
col_transformer = ColumnTransformer([numeric_columns, categorical_columns],
                                    verbose_feature_names_out=False)

col_transformer
# Out:
# ColumnTransformer(transformers=[Index(['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars',
#        'potass', 'vitamins', 'weight', 'cups'],
#       dtype='object'),
#                                 Index(['name', 'mfr', 'type', 'shelf'], dtype='object')],
#                   verbose_feature_names_out=False)

# %%
"""# Making a numeric tuple for ColumnTransformer
# PREPROCESSING PIPELINE FOR NUMERIC DATA
# Save list of column names
numeric_columns = X_train.select_dtypes("number").columns
#print("Numeric Columns:", numeric_columns)
# Instantiate the imputer object from the SimpleImputer class with strategy 'median'
impute_median = SimpleImputer(strategy='median')
scaler = StandardScaler()
# Fit the imputer object on the numeric training data with .fit()
impute_median.fit(X_train[numeric_columns])
# Transform the training data
X_train_num_imputed = impute_median.transform(X_train[numeric_columns])
# Transfrom the testing data
X_test_num_imputed = impute_median.transform(X_test[numeric_columns])
# Make a numeric preprocessing pipeline
numeric_pipeline = make_pipeline(impute_median, scaler)
numeric_pipeline
#or use numeric_pipeline = Pipeline([('imputer', SimpleImputer(strategy='median')),('scaler', StandardScaler())])

# Pipeline 1: For numeric columns
numeric_pipeline = Pipeline([('imputer', SimpleImputer(strategy='mean')),('scaler', StandardScaler())])

numeric_pipeline_tuple = ('numeric_pipeline', numeric_pipeline, numeric_columns)

categorical_columns = X_train.select_dtypes(exclude=['number']).columns
# Pipeline 2: For categorical columns
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent'))])

categorical_pipeline_tuple = ('categorical_pipeline', categorical_pipeline, categorical_columns)
categorical_pipeline_tuple

# Pipeline 3: For both numeric and categorical columns (using ColumnTransformer)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline, numeric_columns),
        ('cat', categorical_pipeline, categorical_columns)
    ]
)
column_transformer_tuple = ('Column_Transformer', preprocessor, numeric_columns, categorical_columns)

# Print the tuples
print("Pipeline 1:", numeric_pipeline_tuple)
print("Pipeline 2:", categorical_pipeline_tuple)
print("Pipeline 3:", column_transformer_tuple)
"""

========================================================================

""" dealing with categorical columns
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

categorical_columns = X_train.select_dtypes(exclude=['number']).columns
# Pipeline 2: For categorical columns
# Pipeline 2: For categorical columns
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent'))
    # Additional transformers can be added as needed
])
categorical_pipeline_tuple = ('categorical_pipeline', categorical_pipeline, categorical_columns)
categorical_pipeline_tuple
"""

===================================================================================
""" # Making a numeric tuple for ColumnTransformer
# PREPROCESSING PIPELINE FOR NUMERIC DATA
# Save list of column names
numeric_columns = X_train.select_dtypes("number").columns
print("Numeric Columns:", numeric_columns)
# Instantiate the imputer object from the SimpleImputer class with strategy 'median'

impute_median = SimpleImputer(strategy='median')
scaler = StandardScaler()
# Fit the imputer object on the numeric training data with .fit()
impute_median.fit(X_train[numeric_columns])
# Transform the training data
X_train_num_imputed = impute_median.transform(X_train[numeric_columns])
# Transfrom the testing data
X_test_num_imputed = impute_median.transform(X_test[numeric_columns])
# Make a numeric preprocessing pipeline
numeric_pipeline = make_pipeline(impute_median, scaler)
numeric_pipeline
#or use numeric_pipeline = Pipeline([('imputer', SimpleImputer(strategy='median')),('scaler', StandardScaler())])
====================================================================================

# Pipeline 1: For numeric columns
#numeric_pipeline = Pipeline([('imputer', SimpleImputer(strategy='mean')),('scaler', StandardScaler())])
#numeric_pipeline
#numeric_pipeline_tuple = ('numeric_pipeline', numeric_pipeline, numeric_columns)
#numeric_pipeline_tuple

"""
# Out:
# ' # Making a numeric tuple for ColumnTransformer\n# PREPROCESSING PIPELINE FOR NUMERIC DATA\n# Save list of column names\nnumeric_columns = X_train.select_dtypes("number").columns\nprint("Numeric Columns:", numeric_columns)\n# Instantiate the imputer object from the SimpleImputer class with strategy \'median\'\n\nimpute_median = SimpleImputer(strategy=\'median\')\nscaler = StandardScaler()\n# Fit the imputer object on the numeric training data with .fit()\nimpute_median.fit(X_train[numeric_columns])\n# Transform the training data\nX_train_num_imputed = impute_median.transform(X_train[numeric_columns])\n# Transfrom the testing data\nX_test_num_imputed = impute_median.transform(X_test[numeric_columns])\n# Make a numeric preprocessing pipeline\nnumeric_pipeline = make_pipeline(impute_median, scaler)\nnumeric_pipeline\n#or use numeric_pipeline = Pipeline([(\'imputer\', SimpleImputer(strategy=\'median\')),(\'scaler\', StandardScaler())])\n\n\n# Pipeline 1: For numeric columns\n#numeric_pipeline = Pipeline([(\'imputer\', SimpleImputer(strategy=\'mean\')),(\'scaler\', StandardScaler())])\n#numeric_pipeline\n#numeric_pipeline_tuple = (\'numeric_pipeline\', numeric_pipeline, numeric_columns)\n#numeric_pipeline_tuple\n\n'

# %%
"""# Define the list of features for this strategy
numeric_columns = X_train.select_dtypes("number").columns
# Instantiate the imputer object from the SimpleImputer class with strategy 'median'
impute_median = SimpleImputer(strategy='median')
# Fit the imputer object on the numeric training data with .fit()
impute_median.fit(X_train[num_cols])
# Transform the training data
X_train_num_imputed = impute_median.transform(X_train[num_cols])
# Transfrom the testing data
X_test_num_imputed = impute_median.transform(X_test[num_cols])
"""
# Out:
# '# Define the list of features for this strategy\nnumeric_columns = X_train.select_dtypes("number").columns\n# Instantiate the imputer object from the SimpleImputer class with strategy \'median\'\nimpute_median = SimpleImputer(strategy=\'median\')\n# Fit the imputer object on the numeric training data with .fit()\nimpute_median.fit(X_train[num_cols])\n# Transform the training data\nX_train_num_imputed = impute_median.transform(X_train[num_cols])\n# Transfrom the testing data\nX_test_num_imputed = impute_median.transform(X_test[num_cols])\n'
